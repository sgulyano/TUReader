# %% [markdown]
# # รวมข้อมูลจาก มธ. และ สกอ.

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 20) # กำหนดให้ Pandas แสดงผลแค่ 20 บรรทัด

# %% [markdown]
# ## รามข้อมูล
#
# เปิดไฟล์ทั้งสองส่วนที่ถูกแก้ไขเบื้องต้นแล้ว

# %%
df1 = pd.read_csv('TUlist.csv', index_col=0)
df2 = pd.read_csv('MUAlist.csv', index_col=0)

# %% [markdown]
# นำมารวมกัน

# %%
df = pd.concat([df1, df2], sort=False)

# %% [markdown]
# #### Sanity Check
# ว่าการแก้ไขข้อมูลเบื้องต้นประสบผลสำเร็จแค่ไหน

# %%
df.columns
# Out:
# Index(['ตำแหน่ง', 'ตำแหน่ง ป.เอก', 'ชื่อ', 'นามสกุล', 'คุณวุฒิ', 'มหาวิทยาลัย',
#        'สาขาวิชา', 'ความเชี่ยวชาญ', 'สถานที่ติดต่อ', 'โทร', 'email', 'สถานะ'],
#       dtype='object')

# %%
# A = np.unique(df.fillna('').iloc[:,0])
A = np.unique(df['สถานที่ติดต่อ'].fillna(''))
A
# Out:
# array(['', '\r\n', '               สถาบันพัฒนาารสาธารณ\r\nสุขอาเซียน',
#        ..., 'โรงเรียนสาธิตฯ',
#        'โรงเรียนสาธิตแห่ง มหาวิทยาลัย เกษตรศาสตร์\r\n ศูนย์วิจัยและ พัฒนาการศึกษา',
#        'โรงเรียนสาธิตแห่ง มหาวิทยาลัย เกษตรศาสตร์ ศูนย์วิจัยและ พัฒนาการศึกษา'],
#       dtype=object)

# %%
from fixwords import fixranks, fixuni
#df.iloc[:,0] = df.fillna('').iloc[:,0].apply(fixranks)
df['มหาวิทยาลัย'] = df['มหาวิทยาลัย'].fillna('').apply(fixuni)

# %%
df
# Out:
#                 ตำแหน่ง ตำแหน่ง ป.เอก      ชื่อ         นามสกุล  \
# 0    ผู้ช่วยศาสตราจารย์           ดร.     สุรภี        รุโจปการ
# 1    ผู้ช่วยศาสตราจารย์           ดร.   อภิชาติ      พลประเสริฐ
# 2        รองศาสตราจารย์           ดร.   จรูญศรี     มาดิลกโกวิท
# 3        รองศาสตราจารย์           ดร.     วรรณี         แกมเกตุ
# 4        รองศาสตราจารย์           ดร.   ใจทิพย์         ณ สงขลา
# 5        รองศาสตราจารย์           ดร.   อาชัญญา        รัตนอุบล
# 6    ผู้ช่วยศาสตราจารย์           ดร.     วิชัย         เสวกงาม
# 7                   NaN           ดร.  ปนัฐษรณ์  จารุชัยนิวัฒน์
# 8                   NaN           ดร.     กีรติ       คุวสานนท์
# 9                   NaN           ดร.   มนสิการ       เฮงสุวรรณ
# ..                  ...           ...       ...             ...
# 774         ศาสตราจารย์           NaN       กมล       เลิศรัตน์
# 775         ศาสตราจารย์           NaN     วิสิฐ         จะวะสิต
# 776         ศาสตราจารย์           NaN      เลขา           มาโนช
# 777         ศาสตราจารย์           NaN     จริยา     ดันทร้ไพแสง
# 778         ศาสตราจารย์           NaN   พรทิพภา    เล็กเจริญสุข
# 779         ศาสตราจารย์           NaN  นิตย์ศรี        แสงเดือน
# 780         ศาสตราจารย์           NaN      ธีระ   เอกสมทราเมษฐ์
# 781         ศาสตราจารย์           NaN    ธีรภาพ  เจริญวิริยะภาพ
# 782         ศาสตราจารย์           NaN     บัญชา      สมบูรณ์สุข
# 783         ศาสตราจารย์           NaN     จิโรจ   ศศิปรียจันทร์
#
#                                                คุณวุฒิ  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# ..                                                 ...
# 774  ตรี: เกษตรศาสตร์  , โท: พันธุศาสตร์  , เอก: Pl...
# 775  ตรี: วิทยาศาสตร์การอาหาร  , โท: Food Science  ...
# 776  ตรี: โรคพืช  , โท: Botany Mycology  , เอก: Pla...
# 777  ตรี: เกษตรศาสตร์  , โท: กีฏวิทยา  , เอก: Entom...
# 778  ตรี: สพ.บ.  , โท: Veterinary Microbiology  , เ...
# 779  ตรี: วิทยาศาสตร์ ทางทะเล  , โท: พันธุศาสตร์  ,...
# 780  ตรี: เกษตรศาสตร์  , โท: เกษตรศาสตร์  , เอก: Do...
# 781  ตรี: เกษตรศาสตร์  , โท: ชีววิทยาสภาวะ แวดล้อม ...
# 782  ตรี: โรคพืช  , โท: ส่งเสริมการเกษตร  , เอก: Ag...
# 783  ตรี: สัตวศาสตร์ สพ.บ. , โท:   , เอก: veterinar...
#
#                   มหาวิทยาลัย        สาขาวิชา  ความเชี่ยวชาญ  \
# 0       จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 1       จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 2       จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 3       จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 4       จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 5       จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 6       จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 7       จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 8       จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 9       จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# ..                        ...             ...            ...
# 774        มหาวิทยาลัยชินวัตร  สาขาเกษตศาสตร์            NaN
# 775      มหาวิทยาลัยมหาสารคาม  สาขาเกษตศาสตร์            NaN
# 776    มหาวิทยาลัยเกษตรศาสตร์  สาขาเกษตศาสตร์            NaN
# 777    มหาวิทยาลัยเกษตรศาสตร์  สาขาเกษตศาสตร์            NaN
# 778    มหาวิทยาลัยเกษตรศาสตร์  สาขาเกษตศาสตร์            NaN
# 779    มหาวิทยาลัยเกษตรศาสตร์  สาขาเกษตศาสตร์            NaN
# 780  มหาวิทยาลัยสงขลานครินทร์  สาขาเกษตศาสตร์            NaN
# 781    มหาวิทยาลัยเกษตรศาสตร์  สาขาเกษตศาสตร์            NaN
# 782  มหาวิทยาลัยสงขลานครินทร์  สาขาเกษตศาสตร์            NaN
# 783     จุฬาลงกรณ์มหาวิทยาลัย  สาขาเกษตศาสตร์            NaN
#
#                                          สถานที่ติดต่อ  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# ..                                                 ...
# 774                                                NaN
# 775                                                NaN
# 776  บ้านเลขที่ 5 ซ.วงศ์สว่าง\r\n ถ.วงศ์สว่าง เขตบา...
# 777                                                NaN
# 778                                                NaN
# 779                                                NaN
# 780                                                NaN
# 781                                                NaN
# 782                                                NaN
# 783                                                NaN
#
#                                      โทร  \
# 0    02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 1    02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 2    02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 3    02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 4    02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 5    02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 6    02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 7    02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 8    02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 9    02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# ..                                   ...
# 774                          0 4320 2361
# 775                          0 2800 2380
# 776                          0 2585 5893
# 777             0 2942 8350, 0 2561 3478
# 778                          0 2797 1900
# 779            0 7553 8034, 081 380 2524
# 780                        0 7428 6138-9
# 781                          0 2942 7131
# 782             0 7428 6120, 0 7428 6134
# 783            0 2218 9412 , 0 2218 9409
#
#                                      email   สถานะ
# 0    edcu57@gmail.com (e-mail address คณะ)     NaN
# 1    edcu57@gmail.com (e-mail address คณะ)     NaN
# 2    edcu57@gmail.com (e-mail address คณะ)     NaN
# 3    edcu57@gmail.com (e-mail address คณะ)     NaN
# 4    edcu57@gmail.com (e-mail address คณะ)     NaN
# 5    edcu57@gmail.com (e-mail address คณะ)     NaN
# 6    edcu57@gmail.com (e-mail address คณะ)     NaN
# 7    edcu57@gmail.com (e-mail address คณะ)     NaN
# 8    edcu57@gmail.com (e-mail address คณะ)     NaN
# 9    edcu57@gmail.com (e-mail address คณะ)     NaN
# ..                                     ...     ...
# 774                                    NaN     NaN
# 775                                    NaN     NaN
# 776                                    NaN  เกษียณ
# 777                                    NaN     NaN
# 778                                    NaN     NaN
# 779                                    NaN  เกษียณ
# 780                                    NaN     NaN
# 781                                    NaN     NaN
# 782                                    NaN     NaN
# 783                                    NaN     NaN
#
# [9482 rows x 12 columns]

# %% [markdown]
# ## แก้รายชื่อซ้ำ
# หารายชื่อทั้งหมดที่ไม่ซ้ำกัน

# %%
u, uid, uin, uc = np.unique(df[['ชื่อ', 'นามสกุล']].fillna('').apply(lambda x: ' '.join(x), axis=1), 
                            return_index=True, 
                            return_inverse=True, 
                            return_counts=True)

# %% [markdown]
# หา boolean index (list ของ True/False ความยาวเท่าจำนวนข้อมูลรายชื่อ) ของรายชื่อที่จะเก็บไว้ โดยทำดังนี้
# * หาชื่อที่ไม่มีซ้ำ แล้วไปค้นหาตำแหน่งในรายชื่อจริง
# * ส่วนชื่อที่มีซ้ำ ให้เก็บบรรทัดล่างสุด (มันจะเป็นข้อมูลใหม่สุด รู้ได้จากตำแหน่งวิชาการที่สูงกว่า)

# %%
idx1 = np.where(uc == 1)[0]

arr = []
for i in np.where(uc > 1)[0]:
    arr.append(np.where(uin == i)[0].max())
    
id1 = (uin[:,np.newaxis]==idx1).any(axis=1)
id1[arr] = True

# %% [markdown]
# เลือกรายชื่อที่ไม่มีข้อมูลซ้ำ

# %%
df2 = df[id1]

# %% [markdown]
# #### Sanity Check
# ว่าการแก้รายชื่อซ้ำสำเร็จ

# %%
u2, _, _, uc2 = np.unique(df2[['ชื่อ', 'นามสกุล']].fillna('').apply(lambda x: ' '.join(x), axis=1), 
                            return_index=True, 
                            return_inverse=True, 
                            return_counts=True)
np.where(uc2 > 1)[0]
# Out:
# array([], dtype=int64)

# %%
df2
# Out:
#                 ตำแหน่ง ตำแหน่ง ป.เอก      ชื่อ          นามสกุล  \
# 3        รองศาสตราจารย์           ดร.     วรรณี          แกมเกตุ
# 4        รองศาสตราจารย์           ดร.   ใจทิพย์          ณ สงขลา
# 9                   NaN           ดร.   มนสิการ        เฮงสุวรรณ
# 15   ผู้ช่วยศาสตราจารย์           ดร.     สุรภี         รุโจปการ
# 17                  NaN           ดร.  ภาวศุทธ์  พิริยะพงษ์รัตน์
# 18   ผู้ช่วยศาสตราจารย์           ดร.   ชื่นชนก          โควินท์
# 19   ผู้ช่วยศาสตราจารย์           ดร.     อรุณี    หงษ์ศิริวัฒน์
# 20   ผู้ช่วยศาสตราจารย์           ดร.  ชญาพิมพ์           อุสาโห
# 21       รองศาสตราจารย์           ดร.   จรูญศรี     มาดิลกโกวิท
# 22   ผู้ช่วยศาสตราจารย์           ดร.     วิรุจ   กิจนันทวิวัฒน์
# ..                  ...           ...       ...              ...
# 774         ศาสตราจารย์           NaN       กมล        เลิศรัตน์
# 775         ศาสตราจารย์           NaN     วิสิฐ          จะวะสิต
# 776         ศาสตราจารย์           NaN      เลขา            มาโนช
# 777         ศาสตราจารย์           NaN     จริยา      ดันทร้ไพแสง
# 778         ศาสตราจารย์           NaN   พรทิพภา     เล็กเจริญสุข
# 779         ศาสตราจารย์           NaN  นิตย์ศรี         แสงเดือน
# 780         ศาสตราจารย์           NaN      ธีระ    เอกสมทราเมษฐ์
# 781         ศาสตราจารย์           NaN    ธีรภาพ   เจริญวิริยะภาพ
# 782         ศาสตราจารย์           NaN     บัญชา       สมบูรณ์สุข
# 783         ศาสตราจารย์           NaN     จิโรจ    ศศิปรียจันทร์
#
#                                                คุณวุฒิ  \
# 3                                                  NaN
# 4                                                  NaN
# 9                                                  NaN
# 15                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# ..                                                 ...
# 774  ตรี: เกษตรศาสตร์  , โท: พันธุศาสตร์  , เอก: Pl...
# 775  ตรี: วิทยาศาสตร์การอาหาร  , โท: Food Science  ...
# 776  ตรี: โรคพืช  , โท: Botany Mycology  , เอก: Pla...
# 777  ตรี: เกษตรศาสตร์  , โท: กีฏวิทยา  , เอก: Entom...
# 778  ตรี: สพ.บ.  , โท: Veterinary Microbiology  , เ...
# 779  ตรี: วิทยาศาสตร์ ทางทะเล  , โท: พันธุศาสตร์  ,...
# 780  ตรี: เกษตรศาสตร์  , โท: เกษตรศาสตร์  , เอก: Do...
# 781  ตรี: เกษตรศาสตร์  , โท: ชีววิทยาสภาวะ แวดล้อม ...
# 782  ตรี: โรคพืช  , โท: ส่งเสริมการเกษตร  , เอก: Ag...
# 783  ตรี: สัตวศาสตร์ สพ.บ. , โท:   , เอก: veterinar...
#
#                   มหาวิทยาลัย        สาขาวิชา  ความเชี่ยวชาญ  \
# 3       จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 4       จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 9       จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 15      จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 17      จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 18      จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 19      จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 20      จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 21      จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# 22      จุฬาลงกรณ์มหาวิทยาลัย       ครุศาสตร์            NaN
# ..                        ...             ...            ...
# 774        มหาวิทยาลัยชินวัตร  สาขาเกษตศาสตร์            NaN
# 775      มหาวิทยาลัยมหาสารคาม  สาขาเกษตศาสตร์            NaN
# 776    มหาวิทยาลัยเกษตรศาสตร์  สาขาเกษตศาสตร์            NaN
# 777    มหาวิทยาลัยเกษตรศาสตร์  สาขาเกษตศาสตร์            NaN
# 778    มหาวิทยาลัยเกษตรศาสตร์  สาขาเกษตศาสตร์            NaN
# 779    มหาวิทยาลัยเกษตรศาสตร์  สาขาเกษตศาสตร์            NaN
# 780  มหาวิทยาลัยสงขลานครินทร์  สาขาเกษตศาสตร์            NaN
# 781    มหาวิทยาลัยเกษตรศาสตร์  สาขาเกษตศาสตร์            NaN
# 782  มหาวิทยาลัยสงขลานครินทร์  สาขาเกษตศาสตร์            NaN
# 783     จุฬาลงกรณ์มหาวิทยาลัย  สาขาเกษตศาสตร์            NaN
#
#                                          สถานที่ติดต่อ  \
# 3                                                  NaN
# 4                                                  NaN
# 9                                                  NaN
# 15                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# ..                                                 ...
# 774                                                NaN
# 775                                                NaN
# 776  บ้านเลขที่ 5 ซ.วงศ์สว่าง\r\n ถ.วงศ์สว่าง เขตบา...
# 777                                                NaN
# 778                                                NaN
# 779                                                NaN
# 780                                                NaN
# 781                                                NaN
# 782                                                NaN
# 783                                                NaN
#
#                                      โทร  \
# 3    02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 4    02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 9    02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 15   02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 17   02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 18   02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 19   02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 20   02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 21   02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# 22   02-218-2565 กด 0 (เบอร์โทรศัพท์คณะ)
# ..                                   ...
# 774                          0 4320 2361
# 775                          0 2800 2380
# 776                          0 2585 5893
# 777             0 2942 8350, 0 2561 3478
# 778                          0 2797 1900
# 779            0 7553 8034, 081 380 2524
# 780                        0 7428 6138-9
# 781                          0 2942 7131
# 782             0 7428 6120, 0 7428 6134
# 783            0 2218 9412 , 0 2218 9409
#
#                                      email   สถานะ
# 3    edcu57@gmail.com (e-mail address คณะ)     NaN
# 4    edcu57@gmail.com (e-mail address คณะ)     NaN
# 9    edcu57@gmail.com (e-mail address คณะ)     NaN
# 15   edcu57@gmail.com (e-mail address คณะ)     NaN
# 17   edcu57@gmail.com (e-mail address คณะ)     NaN
# 18   edcu57@gmail.com (e-mail address คณะ)     NaN
# 19   edcu57@gmail.com (e-mail address คณะ)     NaN
# 20   edcu57@gmail.com (e-mail address คณะ)     NaN
# 21   edcu57@gmail.com (e-mail address คณะ)     NaN
# 22   edcu57@gmail.com (e-mail address คณะ)     NaN
# ..                                     ...     ...
# 774                                    NaN     NaN
# 775                                    NaN     NaN
# 776                                    NaN  เกษียณ
# 777                                    NaN     NaN
# 778                                    NaN     NaN
# 779                                    NaN  เกษียณ
# 780                                    NaN     NaN
# 781                                    NaN     NaN
# 782                                    NaN     NaN
# 783                                    NaN     NaN
#
# [8257 rows x 12 columns]

# %% [markdown]
# บันทึกลงไฟล์ CSV

# %%
df2.to_csv('readerlist.csv', encoding='utf-8-sig', index=False)
